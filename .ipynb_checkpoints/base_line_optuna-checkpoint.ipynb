# %%
import pandas as pd
import numpy as np
import os
from catboost import CatBoostClassifier
from encoding_function import low_frequency_to_others
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 데이터 불러오기
# - 학습: 2023년도 이전
# - 검증: 2023년
# - 테스트: 2024년

# %%
def add_y(df):
    df['rank'] = df['rank'].replace(0, 6)

    target_cols = [
        '단승', '복승', '삼복승'
    ]
    for i, col in enumerate(target_cols):
        condition_target = df['rank'] <= i+1
        df.loc[condition_target, col] = 1

    df[target_cols] = df[target_cols].fillna(0)
    df.drop(['rank'], axis=1, inplace=True)
    return df


ROOT_DIR = "data"
RANDOM_STATE = 999

train = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
test = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

train = add_y(train)
test = add_y(test)

print(train.shape, test.shape)
# Out:
# (79950, 45) (6102, 45)

# %% [markdown]
# ## 사용하지 않는 feature drop

# %% [markdown]
# - 전일 성적을 어떻게 반영할지

# %%
def drop_columns_from_datasets(df):
    drop_cols = [
        '연도', '회차', '일차', '경주번호',
        '금일출주경주',
        '모터번호', '전탑승선수1', '전탑승선수2',
        '보트번호', '특이사항',
        '전일성적'
    ]

    df = df.drop(drop_cols, axis=1)

    return df


train = drop_columns_from_datasets(train)
test = drop_columns_from_datasets(test)

print(train.shape, test.shape)
# Out:
# (79950, 34) (6102, 34)

# %% [markdown]
# ## 일부 숫자형 변수 변환

# %% [markdown]
# - 코스별 성적/경기수 분리

# %%
def separation_course(df):
    col_list = [
        '코스_1코스', '코스_2코스', '코스_3코스', '코스_4코스', '코스_5코스', '코스_6코스'
    ]
    for col in col_list:
        df[[f'{col[3:]}_성적', f'{col[3:]}_경기수']] = df[col].fillna('').str.split('/', expand=True)

    df.drop(col_list, axis=1, inplace=True)

    return df
        


train = separation_course(train)
test = separation_course(test)

print(train.shape, test.shape)
# Out:
# (79950, 40) (6102, 40)

# %% [markdown]
# - 코스별 성적 스무딩

# %%
def apply_laplace_smoothing(df, col, global_mean, alpha):
    # 경기수 0인 값이 너무 높게 나오는 경향이 있어 분모에 상수 1 추가(없애도 됨)
    encoded_value = (df[f'{col}_성적'] * df[f'{col}_경기수'] + global_mean * alpha) / (1 + df[f'{col}_경기수'] + alpha)
    df[f'{col}_성적'] = encoded_value

    return df

def laplace_smoothing_to_course(train, val=None, alpha=1):
    col_list = [
        '1코스', '2코스', '3코스', '4코스', '5코스', '6코스'
    ]
    for col in col_list:
        train[f'{col}_성적'] = train[f'{col}_성적'].astype(float)
        train[f'{col}_경기수'] = train[f'{col}_경기수'].astype(float)
        if val is not None:
            val[f'{col}_성적'] = val[f'{col}_성적'].astype(float)
            val[f'{col}_경기수'] = val[f'{col}_경기수'].astype(float)

    # Train 데이터에서 글로벌 평균 계산
    global_means = {col: train[f'{col}_성적'].mean() for col in col_list}

    for col in col_list:
        # Train 데이터에 라플라스 스무딩 적용
        train = apply_laplace_smoothing(train, col, global_means[col], alpha)
        train.drop(f'{col}_경기수', axis=1, inplace=True)

    if val is not None:
        for col in col_list:
            # Validation 데이터에 Train에서 구한 글로벌 평균으로 라플라스 스무딩 적용
            val = apply_laplace_smoothing(val, col, global_means[col], alpha)
            val.drop(f'{col}_경기수', axis=1, inplace=True)

    if val is not None:
        return train, val
    else:
        return train


train, test = laplace_smoothing_to_course(train, test, alpha=1) # 알파가 작을수록 빈도수에 가깝세, 알파가 클수록 전체 평균에 가깝게
print(train.shape, test.shape)
# Out:
# (79950, 34) (6102, 34)

# %%
def set_course_scores(df):
    # '코스_성적' 열을 초기화
    df['코스_성적'] = 0

    # '번호' 열에 따른 '코스_성적' 값 설정
    for i in range(1, 7):
        mask = df['번호'] == i
        df.loc[mask, '코스_성적'] = df.loc[mask, f'{i}코스_성적']

    # 제거할 열 목록
    drop_cols = [f'{i}코스_성적' for i in range(1, 7)]

    # 열 제거
    df = df.drop(columns=drop_cols)

    return df


from sklearn.decomposition import PCA
def apply_pca(df_train, df_val, n_components=2):
    course_cols = [f'{i}코스_성적' for i in range(1, 7)]

    pca = PCA(n_components=n_components)
    pca.fit(df_train[course_cols])

    # 훈련 데이터에 PCA 변환 적용 (transform)
    train_pca = pca.transform(df_train[course_cols])
    for i in range(n_components):
        df_train[f'PCA_{i+1}'] = train_pca[:, i]

    # 검증 데이터에 동일한 PCA 변환 적용 (transform)
    val_pca = pca.transform(df_val[course_cols])
    for i in range(n_components):
        df_val[f'PCA_{i+1}'] = val_pca[:, i]

    # 각 컴포넌트별 분산 설명 비율 출력
    explained_variance_ratios = pca.explained_variance_ratio_
    for i, ratio in enumerate(explained_variance_ratios):
        print(f"PCA Component {i+1}: {ratio:.4f} variance explained")

    return df_train, df_val


train = set_course_scores(train)
test = set_course_scores(test)

# %% [markdown]
# - 최근 8경기 착순 분리

# %% [markdown]
# - 최근 8경기를 어떻게 반영할지

# %%
def split_last_eight_rank(df):
    for i in range(0, 4):
        df[f'최근{i+1}경기_착순'] = df['최근8경주_착순'].str[i]
    for j in range(5, 9):
        df[f'최근{j}경기_착순'] = df['최근8경주_착순'].str[j]
        
    df.drop('최근8경주_착순', axis=1, inplace=True)
        
    return df

def adjust_for_top3(df):
    col_list = [
        '최근1경기_착순', '최근2경기_착순', '최근3경기_착순', '최근4경기_착순',
        '최근5경기_착순', '최근6경기_착순', '최근7경기_착순', '최근8경기_착순'
    ]
    
    for col in col_list:
    # 순위가 1, 2, 3이 아닌 경우, 결측인 경우, 6으로 조정
    # (일반화된 성능을 위해 + 3등내에 드는게 중요)
        df[col] = df[col].apply(lambda x: x if x in ['1', '2', '3'] else '-1')

    return df


train = split_last_eight_rank(train)
train = adjust_for_top3(train)

test = split_last_eight_rank(test)
test = adjust_for_top3(test)

print(train.shape, test.shape)
# Out:
# (79950, 36) (6102, 36)

# %% [markdown]
# ## 범주형 변수 확인

# %%
def cal_cat_cols(train, val=None):
    objective_cols = []

    # 특정 문자열이 포함된 열을 범주형 변수로 지정
    cat_kerword_list = ['번호', '기수', '경기_착순']
    for col in train.columns:
        if any(sub in col for sub in cat_kerword_list):
            objective_cols.append(col)
            train[col] = train[col].astype('str')
            val[col] = val[col].astype('str')
            
    # 나머지 열에 대해 숫자형 변환 시도
    for col in train.columns:
        if col in objective_cols:
            continue  # 이미 범주형으로 처리된 열은 제외
        try:
            # 'float' 타입으로 변환 시도
            train[col] = train[col].astype('float')
            val[col] = val[col].astype('float')
        except:
            objective_cols.append(col)

    cat_features = list(set(objective_cols) - set(['rank', 'Race_ID']))
    cat_features = [feature for feature in cat_features if '단승' not in feature]
    cat_features = [feature for feature in cat_features if '복승' not in feature]
    cat_features = [feature for feature in cat_features if '삼복승' not in feature]

    return cat_features


# cat_features = cal_cat_cols(train, test)
# cat_features

# %% [markdown]
# ## X, y 분리

# %%
drop_cols = [
    'Race_ID', '번호', '단승', '복승', '삼복승', '선수명', '기수'
]

X_train = train.drop(drop_cols, axis=1)
y_train = train[['단승']]
X_test = test.drop(drop_cols, axis=1)
y_test = test[['단승']]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (79950, 29) (79950, 1) (6102, 29) (6102, 1)

# %%
def reshape_race_data(df, players_per_race=6):
    # numpy 배열로 변환
    values = df.values

    # 데이터 형태 변환 (6개의 행을 1개의 행으로)
    reshaped_values = values.reshape(-1, players_per_race * values.shape[1])

    # 새로운 컬럼 이름 생성
    columns = [f'{col}_{i+1}번선수' for i in range(players_per_race) for col in df.columns]

    # 재구성된 DataFrame 생성
    reshaped_df = pd.DataFrame(reshaped_values, columns=columns)

    return reshaped_df

X_train = reshape_race_data(X_train, players_per_race=6)
y_train = reshape_race_data(y_train, players_per_race=6)
y_train = np.array(y_train).astype(int)

X_test = reshape_race_data(X_test, players_per_race=6)
y_test = reshape_race_data(y_test, players_per_race=6)
y_test = np.array(y_test).astype(int)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (13325, 174) (13325, 6) (1017, 174) (1017, 6)

# %%
def low_to_others(train, val, threshold=5, is_train=True, verbose=False):
    cat_features = cal_cat_cols(train, val)
    if is_train==False:
        cat_features = list(set(cat_features) - set(['Race_ID_1번선수', 'Race_ID_2번선수', 'Race_ID_3번선수', 'Race_ID_4번선수', 'Race_ID_5번선수', 'Race_ID_6번선수']))

    for col in cat_features:
        unifier = low_frequency_to_others(threshold=threshold, verbose=verbose)
        train[col] = unifier.fit_transform(train[col])
        val[col] = unifier.transform(val[col])

    return train, val

X_train, X_test = low_to_others(X_train, X_test, threshold=5, verbose=False)

# %%
def all_precoess(train, val, target='단승', is_train=True):
    train = add_y(train)
    if is_train:
        val = add_y(val)
    
    train = drop_columns_from_datasets(train)
    val = drop_columns_from_datasets(val)

    train = separation_course(train)
    val = separation_course(val)

    train, val = laplace_smoothing_to_course(train, val, alpha=1)

    # train = set_course_scores(train)
    # val = set_course_scores(val)

    train = split_last_eight_rank(train)
    train = adjust_for_top3(train)
    
    val = split_last_eight_rank(val)
    val = adjust_for_top3(val)

    # train, val = low_to_others(train, val, threshold=10, verbose=False)
    
    if is_train:
        drop_cols = [
            'Race_ID', '번호', '단승', '복승', '삼복승', '선수명', '기수'
        ]
    else:
        drop_cols = [
            '번호', '선수명', '기수'
        ]
    
    X_train = train.drop(drop_cols, axis=1)
    y_train = train[[target]]
    X_train = reshape_race_data(X_train, players_per_race=6)
    y_train = reshape_race_data(y_train, players_per_race=6)
    y_train = np.array(y_train).astype(int)

    X_val = val.drop(drop_cols, axis=1)
    X_val = reshape_race_data(X_val, players_per_race=6)
    if is_train:
        y_val = val[[target]]
        y_val = reshape_race_data(y_val, players_per_race=6)
        y_val = np.array(y_val).astype(int)

    X_train, X_val = low_to_others(X_train, X_val, threshold=10, is_train=is_train, verbose=False)
    
    if is_train:
        return X_train, y_train, X_val, y_val
    else:
        return X_train, y_train, X_val
    
train = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
test = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

X_train, y_train, X_test, y_test = all_precoess(train, test, is_train=True)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (13325, 204) (13325, 6) (1017, 204) (1017, 6)

# %%
from model_function import evaluate_

class custom_CatBoostClassifier():
    def __init__(self, params_list):
        self.models = [CatBoostClassifier(**params_list[i]) for i in range(6)]

    def fit(self, X, y, eval_set=None, cat_features=None):
        y = np.array(y)  # y를 numpy 배열로 변환
        if eval_set is not None:
            X_val, y_val = eval_set

        for i in range(6):
            y_i = y[:, i]  # i번째 레이블에 대한 y 값

            if eval_set is not None:
                y_val_i = y_val[:, i]  # i번째 레이블에 대한 y_val 값
                eval_set_i = (X_val, y_val_i)
                self.models[i].fit(
                    X, y_i,
                    eval_set=eval_set_i,
                    cat_features=cat_features
                )
            else:
                eval_set_i = None
                self.models[i].fit(
                    X, y_i,
                    cat_features=cat_features
                )

    def predict(self, X):
        preds = [model.predict(X) for model in self.models]
        return np.vstack(preds).T

    def predict_proba(self, X):
        probas = [model.predict_proba(X)[:, 1] for model in self.models]
        return np.vstack(probas).T

def objective(trial):
    seed = 42
    target_value='복승'
    params_list = []
    params_1 = {
        'random_seed': seed,
        'iterations': 200,
        'learning_rate': trial.suggest_float('learning_rate_label_1', 0.005, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg_label_1', 0.0001, 10),
        'class_weights': {0: 1.0, 1: trial.suggest_float('class_weight_for_1_label_1', 0.5, 5.0)},
        'verbose': 0,
    }
    params_list.append(params_1)
    params_2 = {
        'random_seed': seed,
        'iterations': 200,
        'learning_rate': trial.suggest_float('learning_rate_label_2', 0.005, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg_label_2', 0.0001, 10),
        'class_weights': {0: 1.0, 1: trial.suggest_float('class_weight_for_1_label_2', 0.5, 5.0)},
        'verbose': 0,
    }
    params_list.append(params_2)
    params_3 = {
        'random_seed': seed,
        'iterations': 200,
        'learning_rate': trial.suggest_float('learning_rate_label_3', 0.005, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg_label_3', 0.0001, 10),
        'class_weights': {0: 1.0, 1: trial.suggest_float('class_weight_for_1_label_3', 0.5, 5.0)},
        'verbose': 0,
    }
    params_list.append(params_3)
    params_4 = {
        'random_seed': seed,
        'iterations': 200,
        'learning_rate': trial.suggest_float('learning_rate_label_4', 0.005, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg_label_4', 0.0001, 10),
        'class_weights': {0: 1.0, 1: trial.suggest_float('class_weight_for_1_label_4', 0.5, 5.0)},
        'verbose': 0,
    }
    params_list.append(params_4)
    params_5 = {
        'random_seed': seed,
        'iterations': 200,
        'learning_rate': trial.suggest_float('learning_rate_label_5', 0.005, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg_label_5', 0.0001, 10),
        'class_weights': {0: 1.0, 1: trial.suggest_float('class_weight_for_1_label_5', 0.5, 5.0)},
        'verbose': 0,
    }
    params_list.append(params_5)
    params_6 = {
        'random_seed': seed,
        'iterations': 200,
        'learning_rate': trial.suggest_float('learning_rate_label_6', 0.005, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg_label_6', 0.0001, 10),
        'class_weights': {0: 1.0, 1: trial.suggest_float('class_weight_for_1_label_6', 0.5, 5.0)},
        'verbose': 0,
    }
    params_list.append(params_6)
    
    train = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
    unique_race_ids = train['Race_ID'].unique()
    kf = KFold(n_splits=5, shuffle=True, random_state=seed)

    scores = []
    for i, (train_race_ids, val_race_ids) in enumerate(kf.split(unique_race_ids)):
        train_ids = unique_race_ids[train_race_ids]
        val_ids = unique_race_ids[val_race_ids]

        train_fold = train[train['Race_ID'].isin(train_ids)].reset_index(drop=True)
        val_fold = train[train['Race_ID'].isin(val_ids)].reset_index(drop=True)

        X_train, y_train, X_val, y_val = all_precoess(train_fold, val_fold, target=target_value, is_train=True)

        model = custom_CatBoostClassifier(params_list)
        
        cat_features = cal_cat_cols(X_train, X_val)
        model.fit(
            X_train, y_train,
            cat_features=cat_features
        )

        y_pred = model.predict_proba(X_val)

        accuracy = evaluate_(y_pred, y_val, target_value)
        scores.append(accuracy)

    print('-'*50)
    print(f'folds 1:{scores[0]}, folds 2:{scores[1]}, folds 3:{scores[2]}, folds 4:{scores[3]}, folds 5:{scores[4]}')
    print(f'AVG Accuracy: {np.mean(scores)}')
    print('-'*50)
    print('-'*50)

    return np.mean(scores)


import optuna

study = optuna.create_study(direction='maximize')

study.optimize(objective, n_trials=200, show_progress_bar=True)

print('Best trial:')
trial = study.best_trial
print(f'  Value: {trial.value}')
print('  Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')
# Out:
# [I 2024-09-05 05:56:08,805] A new study created in memory with name: no-name-b2a570a0-9740-44da-817e-8a06174b3cd6
#   0%|          | 0/200 [00:00<?, ?it/s]
# --------------------------------------------------
# folds 1:0.2424015009380863, folds 2:0.24765478424015008, folds 3:0.2424015009380863, folds 4:0.23114446529080676, folds 5:0.2604127579737336
# AVG Accuracy: 0.2448030018761726
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 06:01:05,623] Trial 0 finished with value: 0.2448030018761726 and parameters: {'learning_rate_label_1': 0.025821706117277167, 'l2_leaf_reg_label_1': 1.6001488208770303, 'class_weight_for_1_label_1': 1.769434846352936, 'learning_rate_label_2': 0.08500461236815327, 'l2_leaf_reg_label_2': 3.4328948001619612, 'class_weight_for_1_label_2': 2.685384223128131, 'learning_rate_label_3': 0.18751252022548864, 'l2_leaf_reg_label_3': 7.162127727782198, 'class_weight_for_1_label_3': 3.7195187992660106, 'learning_rate_label_4': 0.07060868657349464, 'l2_leaf_reg_label_4': 5.335621379458535, 'class_weight_for_1_label_4': 1.9401539331098316, 'learning_rate_label_5': 0.16944557515102676, 'l2_leaf_reg_label_5': 0.1202547902257664, 'class_weight_for_1_label_5': 3.7859090138234355, 'learning_rate_label_6': 0.04256882098731818, 'l2_leaf_reg_label_6': 7.244449885915591, 'class_weight_for_1_label_6': 0.6755499005328085}. Best is trial 0 with value: 0.2448030018761726.
# --------------------------------------------------
# folds 1:0.23752345215759849, folds 2:0.25365853658536586, folds 3:0.24878048780487805, folds 4:0.23527204502814258, folds 5:0.2544090056285178
# AVG Accuracy: 0.24592870544090056
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 06
716337790737, 'class_weight_for_1_label_4': 0.5380965092383936, 'learning_rate_label_5': 0.15225674244692122, 'l2_leaf_reg_label_5': 2.688808509787641, 'class_weight_for_1_label_5': 0.6590109541620137, 'learning_rate_label_6': 0.14645355593516995, 'l2_leaf_reg_label_6': 7.195951805657039, 'class_weight_for_1_label_6': 3.746582378241446}. Best is trial 1 with value: 0.24592870544090056.
# --------------------------------------------------
# folds 1:0.23939962476547844, folds 2:0.2525328330206379, folds 3:0.24427767354596622, folds 4:0.24165103189493434, folds 5:0.25966228893058163
# AVG Accuracy: 0.24750469043151968
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 07:05:15,907] Trial 13 finished with value: 0.24750469043151968 and parameters: {'learning_rate_label_1': 0.06681838276493313, 'l2_leaf_reg_label_1': 3.777032883656113, 'class_weight_for_1_label_1': 2.4465840886201002, 'learning_rate_label_2': 0.05830545500236317, 'l2_leaf_reg_label_2': 5.70623039135344, 'class_weight_for_1_label_2': 3.6037646272175508, 'learning_rate_label_3': 0.16921665123411772, 'l2_leaf_reg_label_3': 4.350107954749538, 'class_weight_for_1_label_3': 4.314592575148872, 'learning_rate_label_4': 0.16293993983927257, 'l2_leaf_reg_label_4': 8.246551611828906, 'class_weight_for_1_label_4': 3.6402661410676993, 'learning_rate_label_5': 0.1132811837707064, 'l2_leaf_reg_label_5': 7.720539513204742, 'class_weight_for_1_label_5': 4.298055351764697, 'learning_rate_label_6': 0.11396052152396072, 'l2_leaf_reg_label_6': 0.8577745251743827, 'class_weight_for_1_label_6': 2.731952841995863}. Best is trial 13 with value: 0.24750469043151968.
# --------------------------------------------------
# folds 1:0.23527204502814258, folds 2:0.25328330206378985, folds 3:0.23414634146341465, folds 4:0.2378986866791745, folds 5:0.24840525328330207
# AVG Accuracy: 0.24180112570356474
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 07:10:12,981] Trial 14 finished with value: 0.24180112570356474 and parameters: {'learning_rate_label_1': 0.07468998658396905, 'l2_leaf_reg_label_1': 3.8991443806669297, 'class_weight_for_1_label_1': 2.1097835940062284, 'learning_rate_label_2': 0.008082125959531325, 'l2_leaf_reg_label_2': 8.864202167312293, 'class_weight_for_1_label_2': 3.632354165034546, 'learning_rate_label_3': 0.1723397370333056, 'l2_leaf_reg_label_3': 3.9603100972104794, 'class_weight_for_1_label_3': 2.186229594318911, 'learning_rate_label_4': 0.1558987016578725, 'l2_leaf_reg_label_4': 9.102493964415054, 'class_weight_for_1_label_4': 3.912944373531431, 'learning_rate_label_5': 0.10763323615522705, 'l2_leaf_reg_label_5': 4.8605191331355755, 'class_weight_for_1_label_5': 4.562505824781892, 'learning_rate_label_6': 0.10654136182611133, 'l2_leaf_reg_label_6': 9.036836845711886, 'class_weight_for_1_label_6': 2.7770003730164974}. Best is trial 13 with value: 0.24750469043151968.
# --------------------------------------------------
# folds 1:0.2559099437148218, folds 2:0.2671669793621013, folds 3:0.2529080675422139, folds 4:0.23977485928705441, folds 5:0.2652908067542214
# AVG Accuracy: 0.25621013133208254
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 07:15:13,251] Trial 15 finished with value: 0.25621013133208254 and parameters: {'learning_rate_label_1': 0.10080422269392615, 'l2_leaf_reg_label_1': 8.126451645806567, 'class_weight_for_1_label_1': 3.6277212128390635, 'learning_rate_label_2': 0.11325861270154099, 'l2_leaf_reg_label_2': 5.480305377258171, 'class_weight_for_1_label_2': 4.181417771708725, 'learning_rate_label_3': 0.06729220083899029, 'l2_leaf_reg_label_3': 5.111152310855241, 'class_weight_for_1_label_3': 4.481029974162509, 'learning_rate_label_4': 0.09183635674945737, 'l2_leaf_reg_label_4': 7.046743001806819, 'class_weight_for_1_label_4': 3.753696565630107, 'learning_rate_label_5': 0.11965339286021093, 'l2_leaf_reg_label_5': 6.864031278714101, 'class_weight_for_1_label_5': 4.256114862699382, 'learning_rate_label_6': 0.15156371542762917, 'l2_leaf_reg_label_6': 6.1358342251121885, 'class_weight_for_1_label_6': 2.7025812442754034}. Best is trial 15 with value: 0.25621013133208254.
# --------------------------------------------------
# folds 1:0.2574108818011257, folds 2:0.2637898686679174, folds 3:0.251031894934334, folds 4:0.2401500938086304, folds 5:0.26754221388367727
# AVG Accuracy: 0.255984990619137
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 07:20:10,286] Trial 16 finished with value: 0.255984990619137 and parameters: {'learning_rate_label_1': 0.09898481729926317, 'l2_leaf_reg_label_1': 8.03643020296516, 'class_weight_for_1_label_1': 3.458863722814975, 'learning_rate_label_2': 0.12173601197901204, 'l2_leaf_reg_label_2': 5.053579297853543, 'class_weight_for_1_label_2': 4.376653607653999, 'learning_rate_label_3': 0.06862026976470732, 'l2_leaf_reg_label_3': 5.1896242035967735, 'class_weight_for_1_label_3': 4.440857838455523, 'learning_rate_label_4': 0.08639264067047848, 'l2_leaf_reg_label_4': 7.134965476756685, 'class_weight_for_1_label_4': 4.250099518393811, 'learning_rate_label_5': 0.11844117963064044, 'l2_leaf_reg_label_5': 7.1621750323541535, 'class_weight_for_1_label_5': 4.27928714681882, 'learning_rate_label_6': 0.15516184682868925, 'l2_leaf_reg_label_6': 5.55438957751622, 'class_weight_for_1_label_6': 2.8541002890729468}. Best is trial 15 with value: 0.25621013133208254.
# --------------------------------------------------
# folds 1:0.25403377110694186, folds 2:0.26866791744840524, folds 3:0.2472795497185741, folds 4:0.24052532833020637, folds 5:0.26153846153846155
# AVG Accuracy: 0.2544090056285178
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 07:25:08,992] Trial 17 finished with value: 0.2544090056285178 and parameters: {'learning_rate_label_1': 0.10471763508227268, 'l2_leaf_reg_label_1': 8.05347020026004, 'class_weight_for_1_label_1': 3.4834642628174675, 'learning_rate_label_2': 0.12358465105087012, 'l2_leaf_reg_label_2': 4.908515293902269, 'class_weight_for_1_label_2': 4.348960141742006, 'learning_rate_label_3': 0.0726457502469372, 'l2_leaf_reg_label_3': 5.524646849702707, 'class_weight_for_1_label_3': 4.899868777037433, 'learning_rate_label_4': 0.08506105756343121, 'l2_leaf_reg_label_4': 6.661630492481109, 'class_weight_for_1_label_4': 4.624426731788025, 'learning_rate_label_5': 0.0765240101317218, 'l2_leaf_reg_label_5': 5.454320845718866, 'class_weight_for_1_label_5': 4.2105376359082225, 'learning_rate_label_6': 0.15708309078661253, 'l2_leaf_reg_label_6': 5.381465863874496, 'class_weight_for_1_label_6': 3.0012065296492736}. Best is trial 15 with value: 0.25621013133208254.
# --------------------------------------------------
# folds 1:0.2544090056285178, folds 2:0.2679174484052533, folds 3:0.25178236397748593, folds 4:0.24953095684803, folds 5:0.2731707317073171
# AVG Accuracy: 0.2593621013133208
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 07
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:09:40,866] Trial 26 finished with value: 0.25335834896810505 and parameters: {'learning_rate_label_1': 0.11758060298573655, 'l2_leaf_reg_label_1': 9.071590927566499, 'class_weight_for_1_label_1': 4.5439976705328835, 'learning_rate_label_2': 0.08501207501204985, 'l2_leaf_reg_label_2': 6.865607888380285, 'class_weight_for_1_label_2': 4.610918520684466, 'learning_rate_label_3': 0.0588424016553437, 'l2_leaf_reg_label_3': 4.86147900840093, 'class_weight_for_1_label_3': 4.708381219590148, 'learning_rate_label_4': 0.07513945492453047, 'l2_leaf_reg_label_4': 3.667047082533736, 'class_weight_for_1_label_4': 4.527804731347082, 'learning_rate_label_5': 0.16175011900206338, 'l2_leaf_reg_label_5': 6.104184136933492, 'class_weight_for_1_label_5': 4.010655003649666, 'learning_rate_label_6': 0.1990734388472509, 'l2_leaf_reg_label_6': 3.412717066871121, 'class_weight_for_1_label_6': 4.50512498632395}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.2544090056285178, folds 2:0.2619136960600375, folds 3:0.2480300187617261, folds 4:0.23602251407129457, folds 5:0.2667917448405253
# AVG Accuracy: 0.25343339587242025
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:14:40,072] Trial 27 finished with value: 0.25343339587242025 and parameters: {'learning_rate_label_1': 0.13543416699594701, 'l2_leaf_reg_label_1': 6.1103482443179065, 'class_weight_for_1_label_1': 2.8965975462023814, 'learning_rate_label_2': 0.12823455358771002, 'l2_leaf_reg_label_2': 7.673180313508887, 'class_weight_for_1_label_2': 4.069476828150952, 'learning_rate_label_3': 0.02913638627148077, 'l2_leaf_reg_label_3': 0.3714541297006604, 'class_weight_for_1_label_3': 4.231114533089513, 'learning_rate_label_4': 0.057174493922819786, 'l2_leaf_reg_label_4': 8.904184153764255, 'class_weight_for_1_label_4': 3.298555499226009, 'learning_rate_label_5': 0.13002154024262574, 'l2_leaf_reg_label_5': 7.5751682694482, 'class_weight_for_1_label_5': 3.533804326351661, 'learning_rate_label_6': 0.12149822616084364, 'l2_leaf_reg_label_6': 4.8715530143989465, 'class_weight_for_1_label_6': 4.687371408163977}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.25666041275797374, folds 2:0.27129455909943717, folds 3:0.24540337711069418, folds 4:0.24052532833020637, folds 5:0.27392120075046905
# AVG Accuracy: 0.2575609756097561
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:19:38,687] Trial 28 finished with value: 0.2575609756097561 and parameters: {'learning_rate_label_1': 0.11254647632698299, 'l2_leaf_reg_label_1': 7.559883105256497, 'class_weight_for_1_label_1': 3.4167206907160885, 'learning_rate_label_2': 0.11120769737219766, 'l2_leaf_reg_label_2': 5.51760034063928, 'class_weight_for_1_label_2': 3.2963567992669986, 'learning_rate_label_3': 0.05773872768758888, 'l2_leaf_reg_label_3': 2.0327301118714374, 'class_weight_for_1_label_3': 2.5116392477097866, 'learning_rate_label_4': 0.026949753606260715, 'l2_leaf_reg_label_4': 7.333704341147064, 'class_weight_for_1_label_4': 3.7894317437612504, 'learning_rate_label_5': 0.09566224622480321, 'l2_leaf_reg_label_5': 6.4028636778393295, 'class_weight_for_1_label_5': 2.9015955558969804, 'learning_rate_label_6': 0.1431867798091757, 'l2_leaf_reg_label_6': 7.566492519246134, 'class_weight_for_1_label_6': 3.7103789056221363}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.23827392120075047, folds 2:0.2529080675422139, folds 3:0.224765478424015, folds 4:0.2348968105065666, folds 5:0.24840525328330207
# AVG Accuracy: 0.23984990619136962
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:24:39,776] Trial 29 finished with value: 0.23984990619136962 and parameters: {'learning_rate_label_1': 0.11261800953397613, 'l2_leaf_reg_label_1': 4.551291614959577, 'class_weight_for_1_label_1': 1.6595439139820793, 'learning_rate_label_2': 0.08910624216520405, 'l2_leaf_reg_label_2': 9.152758544201902, 'class_weight_for_1_label_2': 3.227096199033267, 'learning_rate_label_3': 0.012211753382362994, 'l2_leaf_reg_label_3': 2.097436596891491, 'class_weight_for_1_label_3': 2.0914724143960015, 'learning_rate_label_4': 0.007590265182453454, 'l2_leaf_reg_label_4': 5.669054362530661, 'class_weight_for_1_label_4': 4.0885990405586705, 'learning_rate_label_5': 0.09318345526665116, 'l2_leaf_reg_label_5': 4.375955387986947, 'class_weight_for_1_label_5': 2.757911716964272, 'learning_rate_label_6': 0.16959206005059593, 'l2_leaf_reg_label_6': 7.4493363081138835, 'class_weight_for_1_label_6': 3.7219246967961066}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.24840525328330207, folds 2:0.25816135084427766, folds 3:0.23377110694183864, folds 4:0.23902439024390243, folds 5:0.2574108818011257
# AVG Accuracy: 0.2473545966228893
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:29:42,848] Trial 30 finished with value: 0.2473545966228893 and parameters: {'learning_rate_label_1': 0.05743798845682735, 'l2_leaf_reg_label_1': 7.224141067618471, 'class_weight_for_1_label_1': 2.0934028378973544, 'learning_rate_label_2': 0.0703501983011234, 'l2_leaf_reg_label_2': 8.1470845620795, 'class_weight_for_1_label_2': 3.0904175891375285, 'learning_rate_label_3': 0.050584726592956944, 'l2_leaf_reg_label_3': 0.11701449088308635, 'class_weight_for_1_label_3': 2.5909718189263438, 'learning_rate_label_4': 0.02538776829946934, 'l2_leaf_reg_label_4': 7.589069635467542, 'class_weight_for_1_label_4': 4.499759247776178, 'learning_rate_label_5': 0.06647331177960294, 'l2_leaf_reg_label_5': 5.7972440999790935, 'class_weight_for_1_label_5': 1.7602287863831296, 'learning_rate_label_6': 0.1388653233482419, 'l2_leaf_reg_label_6': 8.804859978878932, 'class_weight_for_1_label_6': 4.076203961418363}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.24465290806754222, folds 2:0.2529080675422139, folds 3:0.24465290806754222, folds 4:0.23939962476547844, folds 5:0.2547842401500938
# AVG Accuracy: 0.2472795497185741
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:34:43,828] Trial 31 finished with value: 0.2472795497185741 and parameters: {'learning_rate_label_1': 0.08751959120498166, 'l2_leaf_reg_label_1': 8.868247268848156, 'class_weight_for_1_label_1': 3.415912603547303, 'learning_rate_label_2': 0.10840059618855231, 'l2_leaf_reg_label_2': 5.572223095827031, 'class_weight_for_1_label_2': 2.0653216853514365, 'learning_rate_label_3': 0.07285921432882093, 'l2_leaf_reg_label_3': 3.331691124404916, 'class_weight_for_1_label_3': 3.650121035148299, 'learning_rate_label_4': 0.06924227858092648, 'l2_leaf_reg_label_4': 6.5823258606437545, 'class_weight_for_1_label_4': 3.678859737575371, 'learning_rate_label_5': 0.11982292052363902, 'l2_leaf_reg_label_5': 6.5839101734849965, 'class_weight_for_1_label_5': 3.8680844593979966, 'learning_rate_label_6': 0.149590203832746, 'l2_leaf_reg_label_6': 7.140586677504169, 'class_weight_for_1_label_6': 3.1979078976357864}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.24615384615384617, folds 2:0.2577861163227017, folds 3:0.2401500938086304, folds 4:0.24090056285178235, folds 5:0.27542213883677297
# AVG Accuracy: 0.25208255159474674
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:39:42,596] Trial 32 finished with value: 0.25208255159474674 and parameters: {'learning_rate_label_1': 0.10499137488889423, 'l2_leaf_reg_label_1': 7.75841118161547, 'class_weight_for_1_label_1': 3.89071457599222, 'learning_rate_label_2': 0.1338200706037894, 'l2_leaf_reg_label_2': 4.527624433210171, 'class_weight_for_1_label_2': 4.691781050994143, 'learning_rate_label_3': 0.09420445718828017, 'l2_leaf_reg_label_3': 2.4385201452339147, 'class_weight_for_1_label_3': 2.348689148392414, 'learning_rate_label_4': 0.04944049450848158, 'l2_leaf_reg_label_4': 7.151579805143276, 'class_weight_for_1_label_4': 3.74164802917151, 'learning_rate_label_5': 0.1726691422537596, 'l2_leaf_reg_label_5': 8.254729366959765, 'class_weight_for_1_label_5': 3.0150059276787884, 'learning_rate_label_6': 0.0841744943527917, 'l2_leaf_reg_label_6': 6.159106263672652, 'class_weight_for_1_label_6': 2.5580484235583825}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.23039399624765478, folds 2:0.25028142589118196, folds 3:0.2427767354596623, folds 4:0.23452157598499063, folds 5:0.2555347091932458
# AVG Accuracy: 0.2427016885553471
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:44:43,375] Trial 33 finished with value: 0.2427016885553471 and parameters: {'learning_rate_label_1': 0.14998468042719204, 'l2_leaf_reg_label_1': 9.772069938146027, 'class_weight_for_1_label_1': 3.5731524071698058, 'learning_rate_label_2': 0.09924661309395569, 'l2_leaf_reg_label_2': 6.453725457109348, 'class_weight_for_1_label_2': 4.301379431151682, 'learning_rate_label_3': 0.06486463253979054, 'l2_leaf_reg_label_3': 1.4037634842140267, 'class_weight_for_1_label_3': 1.607376025049176, 'learning_rate_label_4': 0.07105685746664636, 'l2_leaf_reg_label_4': 8.819078329569216, 'class_weight_for_1_label_4': 3.1568073653696933, 'learning_rate_label_5': 0.09845276163938055, 'l2_leaf_reg_label_5': 7.054981463603572, 'class_weight_for_1_label_5': 4.509248119467951, 'learning_rate_label_6': 0.17447421915809797, 'l2_leaf_reg_label_6': 7.693811865317842, 'class_weight_for_1_label_6': 1.8977018034148663}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.2544090056285178, folds 2:0.2652908067542214, folds 3:0.23377110694183864, folds 4:0.2401500938086304, folds 5:0.26604127579737336
# AVG Accuracy: 0.25193245778611634
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:49:43,928] Trial 34 finished with value: 0.25193245778611634 and parameters: {'learning_rate_label_1': 0.16351918492633877, 'l2_leaf_reg_label_1': 8.728325658034485, 'class_weight_for_1_label_1': 4.313224035120769, 'learning_rate_label_2': 0.08792852118613902, 'l2_leaf_reg_label_2': 5.5456852178767795, 'class_weight_for_1_label_2': 3.9349592543535596, 'learning_rate_label_3': 0.031192642471809563, 'l2_leaf_reg_label_3': 3.779732599340894, 'class_weight_for_1_label_3': 3.264912708160587, 'learning_rate_label_4': 0.023894922291849037, 'l2_leaf_reg_label_4': 9.964906784798313, 'class_weight_for_1_label_4': 3.524666147074673, 'learning_rate_label_5': 0.1437103495880613, 'l2_leaf_reg_label_5': 6.39325284899906, 'class_weight_for_1_label_5': 3.348827227773197, 'learning_rate_label_6': 0.15536359800840716, 'l2_leaf_reg_label_6': 6.794325867935519, 'class_weight_for_1_label_6': 4.985409399311352}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.23527204502814258, folds 2:0.25178236397748593, folds 3:0.23452157598499063, folds 4:0.23752345215759849, folds 5:0.2577861163227017
# AVG Accuracy: 0.24337711069418386
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 08:54:43,976] Trial 35 finished with value: 0.24337711069418386 and parameters: {'learning_rate_label_1': 0.14055312828860309, 'l2_leaf_reg_label_1': 6.992123888431027, 'class_weight_for_1_label_1': 3.2117209116878414, 'learning_rate_label_2': 0.11818144559876693, 'l2_leaf_reg_label_2': 3.961230239997047, 'class_weight_for_1_label_2': 3.3747213859505742, 'learning_rate_label_3': 0.12453659458215596, 'l2_leaf_reg_label_3': 4.784197665324066, 'class_weight_for_1_label_3': 1.7952813846036293, 'learning_rate_label_4': 0.1132776623730822, 'l2_leaf_reg_label_4': 7.821155675559493, 'class_weight_for_1_label_4': 3.9685689873430747, 'learning_rate_label_5': 0.11009149312098812, 'l2_leaf_reg_label_5': 4.891751039426969, 'class_weight_for_1_label_5': 4.9824092852676785, 'learning_rate_label_6': 0.12496035649738486, 'l2_leaf_reg_label_6': 5.9580554980594655, 'class_weight_for_1_label_6': 3.4668971224449736}. Best is trial 18 with value: 0.2593621013133208.
# --------------------------------------------------
# folds 1:0.2544090056285178, folds 2:0.26566604127579735, folds 3:0.2529080675422139, folds 4:0.2348968105065666, folds 5:0.2682926829268293
# AVG Accuracy: 0.255234521575985
# --------------------------------------------------
# --------------------------------------------------
# ...
# --------------------------------------------------
# folds 1:0.24765478424015008, folds 2:0.2652908067542214, folds 3:0.24765478424015008, folds 4:0.23564727954971856, folds 5:0.2671669793621013
# AVG Accuracy: 0.25268292682926824
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 22:49:43,094] Trial 189 finished with value: 0.25268292682926824 and parameters: {'learning_rate_label_1': 0.13559058528603735, 'l2_leaf_reg_label_1': 9.78245973796036, 'class_weight_for_1_label_1': 3.91115069957726, 'learning_rate_label_2': 0.10338820718581528, 'l2_leaf_reg_label_2': 9.265934529269257, 'class_weight_for_1_label_2': 3.965089201241965, 'learning_rate_label_3': 0.07658885232248412, 'l2_leaf_reg_label_3': 1.8365265480953001, 'class_weight_for_1_label_3': 4.720367625216833, 'learning_rate_label_4': 0.04163248887486909, 'l2_leaf_reg_label_4': 7.155733571585345, 'class_weight_for_1_label_4': 4.316383288254079, 'learning_rate_label_5': 0.14428156244889034, 'l2_leaf_reg_label_5': 7.053383288470609, 'class_weight_for_1_label_5': 3.293327135398675, 'learning_rate_label_6': 0.17481459897141993, 'l2_leaf_reg_label_6': 8.497928711139451, 'class_weight_for_1_label_6': 3.243378173829672}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.2401500938086304, folds 2:0.2544090056285178, folds 3:0.25065666041275797, folds 4:0.23752345215759849, folds 5:0.2671669793621013
# AVG Accuracy: 0.2499812382739212
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 22:56:39,725] Trial 190 finished with value: 0.2499812382739212 and parameters: {'learning_rate_label_1': 0.12712089513853075, 'l2_leaf_reg_label_1': 8.029876270652576, 'class_weight_for_1_label_1': 3.800384861081635, 'learning_rate_label_2': 0.07025507841795917, 'l2_leaf_reg_label_2': 5.995467386378221, 'class_weight_for_1_label_2': 2.609718646160095, 'learning_rate_label_3': 0.11988488557072197, 'l2_leaf_reg_label_3': 1.3409690327633577, 'class_weight_for_1_label_3': 4.460350157768497, 'learning_rate_label_4': 0.03347690592447379, 'l2_leaf_reg_label_4': 8.173844134925035, 'class_weight_for_1_label_4': 3.59808133344074, 'learning_rate_label_5': 0.05009130006494032, 'l2_leaf_reg_label_5': 7.442766091057013, 'class_weight_for_1_label_5': 3.506614964639288, 'learning_rate_label_6': 0.1625023055110113, 'l2_leaf_reg_label_6': 7.748978744937317, 'class_weight_for_1_label_6': 2.717071290811935}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.2525328330206379, folds 2:0.26454033771106944, folds 3:0.2551594746716698, folds 4:0.2348968105065666, folds 5:0.26754221388367727
# AVG Accuracy: 0.2549343339587242
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:03:03,894] Trial 191 finished with value: 0.2549343339587242 and parameters: {'learning_rate_label_1': 0.11351943351018944, 'l2_leaf_reg_label_1': 7.589683589355504, 'class_weight_for_1_label_1': 3.4365930777604445, 'learning_rate_label_2': 0.11043788535882851, 'l2_leaf_reg_label_2': 5.171459734064743, 'class_weight_for_1_label_2': 3.894158997159414, 'learning_rate_label_3': 0.05089298297624517, 'l2_leaf_reg_label_3': 2.0557614437845864, 'class_weight_for_1_label_3': 4.367520950290022, 'learning_rate_label_4': 0.024480991591701896, 'l2_leaf_reg_label_4': 7.082916558771359, 'class_weight_for_1_label_4': 3.9058245823640405, 'learning_rate_label_5': 0.033187347697389666, 'l2_leaf_reg_label_5': 6.418293210895877, 'class_weight_for_1_label_5': 3.3933445820644215, 'learning_rate_label_6': 0.0654691484319434, 'l2_leaf_reg_label_6': 7.5287332152123705, 'class_weight_for_1_label_6': 3.65995702146673}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.2472795497185741, folds 2:0.26641651031894936, folds 3:0.25328330206378985, folds 4:0.24690431519699813, folds 5:0.2701688555347092
# AVG Accuracy: 0.2568105065666041
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:09:27,916] Trial 192 finished with value: 0.2568105065666041 and parameters: {'learning_rate_label_1': 0.11135514735937548, 'l2_leaf_reg_label_1': 8.15310052970587, 'class_weight_for_1_label_1': 3.6092890402208777, 'learning_rate_label_2': 0.11661608696952117, 'l2_leaf_reg_label_2': 5.314931132246165, 'class_weight_for_1_label_2': 3.812693775290054, 'learning_rate_label_3': 0.05842111624146362, 'l2_leaf_reg_label_3': 1.6491654279711045, 'class_weight_for_1_label_3': 4.569487897290289, 'learning_rate_label_4': 0.021971361406590284, 'l2_leaf_reg_label_4': 7.413019924386914, 'class_weight_for_1_label_4': 3.508933338389144, 'learning_rate_label_5': 0.0946600715188075, 'l2_leaf_reg_label_5': 5.975470225560694, 'class_weight_for_1_label_5': 3.040377068793725, 'learning_rate_label_6': 0.0476837890701664, 'l2_leaf_reg_label_6': 7.0783066421337395, 'class_weight_for_1_label_6': 3.958851620608777}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.25966228893058163, folds 2:0.2724202626641651, folds 3:0.2525328330206379, folds 4:0.2378986866791745, folds 5:0.2652908067542214
# AVG Accuracy: 0.2575609756097561
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:16:06,477] Trial 193 finished with value: 0.2575609756097561 and parameters: {'learning_rate_label_1': 0.09659171601687791, 'l2_leaf_reg_label_1': 7.869938064455168, 'class_weight_for_1_label_1': 3.71739698543756, 'learning_rate_label_2': 0.0899362012248495, 'l2_leaf_reg_label_2': 9.794714890018712, 'class_weight_for_1_label_2': 4.029361713930887, 'learning_rate_label_3': 0.06388491998711253, 'l2_leaf_reg_label_3': 2.330501056957945, 'class_weight_for_1_label_3': 4.502077988395935, 'learning_rate_label_4': 0.037365246037681966, 'l2_leaf_reg_label_4': 7.931435294905153, 'class_weight_for_1_label_4': 3.713361323558458, 'learning_rate_label_5': 0.09927244258426135, 'l2_leaf_reg_label_5': 6.113064055468878, 'class_weight_for_1_label_5': 3.177182075921263, 'learning_rate_label_6': 0.05253660714746454, 'l2_leaf_reg_label_6': 8.136418606159717, 'class_weight_for_1_label_6': 3.4718015797124266}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.22401500938086305, folds 2:0.23039399624765478, folds 3:0.22288930581613509, folds 4:0.22814258911819887, folds 5:0.23639774859287055
# AVG Accuracy: 0.22836772983114448
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:25:01,236] Trial 194 finished with value: 0.22836772983114448 and parameters: {'learning_rate_label_1': 0.103198119784582, 'l2_leaf_reg_label_1': 8.440661965184354, 'class_weight_for_1_label_1': 1.0989146638354226, 'learning_rate_label_2': 0.09893649236893948, 'l2_leaf_reg_label_2': 5.967933724591656, 'class_weight_for_1_label_2': 3.40358879774692, 'learning_rate_label_3': 0.05391552269815844, 'l2_leaf_reg_label_3': 5.200478692470344, 'class_weight_for_1_label_3': 4.23652558807668, 'learning_rate_label_4': 0.016634447232726456, 'l2_leaf_reg_label_4': 7.761571962821464, 'class_weight_for_1_label_4': 3.1279996075975127, 'learning_rate_label_5': 0.12373395490930769, 'l2_leaf_reg_label_5': 6.835074067767196, 'class_weight_for_1_label_5': 3.6623317967448856, 'learning_rate_label_6': 0.05810406887550299, 'l2_leaf_reg_label_6': 7.30828517389029, 'class_weight_for_1_label_6': 2.8604128041618875}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.25365853658536586, folds 2:0.2724202626641651, folds 3:0.24090056285178235, folds 4:0.23939962476547844, folds 5:0.2716697936210131
# AVG Accuracy: 0.2556097560975609
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:34:00,822] Trial 195 finished with value: 0.2556097560975609 and parameters: {'learning_rate_label_1': 0.11995929813359679, 'l2_leaf_reg_label_1': 9.219925715955684, 'class_weight_for_1_label_1': 3.345225320078975, 'learning_rate_label_2': 0.11379845167783557, 'l2_leaf_reg_label_2': 7.845150626834447, 'class_weight_for_1_label_2': 4.1566508524385215, 'learning_rate_label_3': 0.06704741344387555, 'l2_leaf_reg_label_3': 2.5987939312715285, 'class_weight_for_1_label_3': 2.946550787224766, 'learning_rate_label_4': 0.044471392013214935, 'l2_leaf_reg_label_4': 7.184183634191304, 'class_weight_for_1_label_4': 3.445426770985102, 'learning_rate_label_5': 0.042960217683089504, 'l2_leaf_reg_label_5': 6.548832734454854, 'class_weight_for_1_label_5': 3.8322440011813717, 'learning_rate_label_6': 0.062111734527076745, 'l2_leaf_reg_label_6': 4.739015007869581, 'class_weight_for_1_label_6': 3.711715557058796}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.25028142589118196, folds 2:0.2604127579737336, folds 3:0.24840525328330207, folds 4:0.2450281425891182, folds 5:0.2619136960600375
# AVG Accuracy: 0.25320825515947465
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:41:25,591] Trial 196 finished with value: 0.25320825515947465 and parameters: {'learning_rate_label_1': 0.11613279042204708, 'l2_leaf_reg_label_1': 9.690057795474837, 'class_weight_for_1_label_1': 3.989469863446248, 'learning_rate_label_2': 0.09301354975979598, 'l2_leaf_reg_label_2': 5.532189397360996, 'class_weight_for_1_label_2': 3.926845367370428, 'learning_rate_label_3': 0.0585896951220446, 'l2_leaf_reg_label_3': 2.175914153558382, 'class_weight_for_1_label_3': 4.677403543513184, 'learning_rate_label_4': 0.02861174320238026, 'l2_leaf_reg_label_4': 7.619634376017653, 'class_weight_for_1_label_4': 3.823279930748695, 'learning_rate_label_5': 0.014094777649722456, 'l2_leaf_reg_label_5': 7.73304311593714, 'class_weight_for_1_label_5': 3.571910639518235, 'learning_rate_label_6': 0.08147477361015038, 'l2_leaf_reg_label_6': 0.9109967031828264, 'class_weight_for_1_label_6': 3.759961764265385}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.25365853658536586, folds 2:0.2551594746716698, folds 3:0.2401500938086304, folds 4:0.24052532833020637, folds 5:0.2682926829268293
# AVG Accuracy: 0.25155722326454033
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:48:20,767] Trial 197 finished with value: 0.25155722326454033 and parameters: {'learning_rate_label_1': 0.13166900284707492, 'l2_leaf_reg_label_1': 7.333017132246362, 'class_weight_for_1_label_1': 3.863801218167812, 'learning_rate_label_2': 0.12049198507808627, 'l2_leaf_reg_label_2': 9.49668212245768, 'class_weight_for_1_label_2': 3.5938675219172453, 'learning_rate_label_3': 0.06184880093612706, 'l2_leaf_reg_label_3': 2.9425472037156566, 'class_weight_for_1_label_3': 2.4659057319941677, 'learning_rate_label_4': 0.03217690345095224, 'l2_leaf_reg_label_4': 6.987468974142635, 'class_weight_for_1_label_4': 4.610022123587926, 'learning_rate_label_5': 0.024986226245507958, 'l2_leaf_reg_label_5': 7.1799086344090535, 'class_weight_for_1_label_5': 3.74755131049881, 'learning_rate_label_6': 0.10362017548054925, 'l2_leaf_reg_label_6': 1.6265472643047654, 'class_weight_for_1_label_6': 3.5343126145923085}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.2547842401500938, folds 2:0.2622889305816135, folds 3:0.24615384615384617, folds 4:0.23151969981238274, folds 5:0.27204502814258913
# AVG Accuracy: 0.25335834896810505
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-05 23:55:14,818] Trial 198 finished with value: 0.25335834896810505 and parameters: {'learning_rate_label_1': 0.11124028600507621, 'l2_leaf_reg_label_1': 8.317168522481989, 'class_weight_for_1_label_1': 4.39301341185394, 'learning_rate_label_2': 0.08183800184956279, 'l2_leaf_reg_label_2': 5.687754758767191, 'class_weight_for_1_label_2': 3.7400298284796, 'learning_rate_label_3': 0.05051000313799141, 'l2_leaf_reg_label_3': 4.95033877475465, 'class_weight_for_1_label_3': 4.098855967611592, 'learning_rate_label_4': 0.060921462671154614, 'l2_leaf_reg_label_4': 8.470969249282506, 'class_weight_for_1_label_4': 3.356689097435052, 'learning_rate_label_5': 0.13741652081256037, 'l2_leaf_reg_label_5': 6.3756373162333135, 'class_weight_for_1_label_5': 3.910857553305375, 'learning_rate_label_6': 0.15944624625862583, 'l2_leaf_reg_label_6': 7.577740637317862, 'class_weight_for_1_label_6': 3.3183143634358103}. Best is trial 122 with value: 0.2601125703564728.
# --------------------------------------------------
# folds 1:0.25328330206378985, folds 2:0.2592870544090056, folds 3:0.24352720450281426, folds 4:0.23902439024390243, folds 5:0.2619136960600375
# AVG Accuracy: 0.25140712945590993
# --------------------------------------------------
# --------------------------------------------------
# [I 2024-09-06 00:02:05,324] Trial 199 finished with value: 0.25140712945590993 and parameters: {'learning_rate_label_1': 0.12160756188038063, 'l2_leaf_reg_label_1': 8.59985762705512, 'class_weight_for_1_label_1': 3.5418793204260144, 'learning_rate_label_2': 0.08567216576100235, 'l2_leaf_reg_label_2': 8.801107120151336, 'class_weight_for_1_label_2': 3.8264131709564224, 'learning_rate_label_3': 0.05601908136982651, 'l2_leaf_reg_label_3': 1.8130161438894448, 'class_weight_for_1_label_3': 4.378949463508004, 'learning_rate_label_4': 0.050526890092929634, 'l2_leaf_reg_label_4': 0.4047200388264751, 'class_weight_for_1_label_4': 4.053373232606834, 'learning_rate_label_5': 0.1283090835394093, 'l2_leaf_reg_label_5': 6.933329260226196, 'class_weight_for_1_label_5': 0.9676074330433955, 'learning_rate_label_6': 0.08847093830730508, 'l2_leaf_reg_label_6': 0.24607174565753542, 'class_weight_for_1_label_6': 2.4806324933047246}. Best is trial 122 with value: 0.2601125703564728.
# Best trial:
#   Value: 0.2601125703564728
#   Params:
#     learning_rate_label_1: 0.09719738901239813
#     l2_leaf_reg_label_1: 8.08214833285572
#     class_weight_for_1_label_1: 3.615033608391579
#     learning_rate_label_2: 0.08986154076025232
#     l2_leaf_reg_label_2: 5.356161464826255
#     class_weight_for_1_label_2: 4.271282409160504
#     learning_rate_label_3: 0.06849990307395196
#     l2_leaf_reg_label_3: 2.885808980448922
#     class_weight_for_1_label_3: 4.367286456552369
#     learning_rate_label_4: 0.09474850624939075
#     l2_leaf_reg_label_4: 6.999359411562832
#     class_weight_for_1_label_4: 2.5335515942659743
#     learning_rate_label_5: 0.08674133482890571
#     l2_leaf_reg_label_5: 7.063997127332498
#     class_weight_for_1_label_5: 3.0492130863383484
#     learning_rate_label_6: 0.15744810753127567
#     l2_leaf_reg_label_6: 1.0798243810773542
#     class_weight_for_1_label_6: 3.0154819061761944

# %%
Best trial:
  Value: 0.2601125703564728
  Params: 
    learning_rate_label_1: 0.09719738901239813
    l2_leaf_reg_label_1: 8.08214833285572
    class_weight_for_1_label_1: 3.615033608391579
    learning_rate_label_2: 0.08986154076025232
    l2_leaf_reg_label_2: 5.356161464826255
    class_weight_for_1_label_2: 4.271282409160504
    learning_rate_label_3: 0.06849990307395196
    l2_leaf_reg_label_3: 2.885808980448922
    class_weight_for_1_label_3: 4.367286456552369
    learning_rate_label_4: 0.09474850624939075
    l2_leaf_reg_label_4: 6.999359411562832
    class_weight_for_1_label_4: 2.5335515942659743
    learning_rate_label_5: 0.08674133482890571
    l2_leaf_reg_label_5: 7.063997127332498
    class_weight_for_1_label_5: 3.0492130863383484
    learning_rate_label_6: 0.15744810753127567
    l2_leaf_reg_label_6: 1.0798243810773542
    class_weight_for_1_label_6: 3.0154819061761944
